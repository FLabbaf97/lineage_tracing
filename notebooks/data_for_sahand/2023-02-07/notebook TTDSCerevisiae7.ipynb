# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bread.data import *
import bread.vis as vis

from pathlib import Path
import matplotlib.pyplot as plt

# %%
datafolder = Path('../../../data/data_from_s41592-022-01603-2/TTDSCerevisiae7')

# %%
seg = Segmentation.from_h5(datafolder / 'TTD_SCerevisiae_7_segmented__time_001_to_104.raw.h5', fov='FOV0')
seg_new = seg.crop(204, 351, 576, 576)
seg_new.write_h5(datafolder / 'colony1_segmentation__time_001_to_104.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'colony1_BF.tif'), 103)
figax = vis.plot_segmentation(seg_new, 103, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'TTD_SCerevisiae_7_segmented__time_001_to_104.raw.h5', fov='FOV0')
seg_new = seg.crop(783, 204, 1152, 1341)
seg_new.write_h5(datafolder / 'colony2_segmentation__time_001_to_104.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'colony2_BF.tif'), 103)
figax = vis.plot_segmentation(seg_new, 103, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'TTD_SCerevisiae_7_segmented__time_001_to_104.raw.h5', fov='FOV0')
seg_new = seg.crop(96, 957, 600, 897)
seg_new.write_h5(datafolder / 'colony3_segmentation__time_001_to_104.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'colony3_BF.tif'), 103)
figax = vis.plot_segmentation(seg_new, 103, cellids=False, figax=figax)

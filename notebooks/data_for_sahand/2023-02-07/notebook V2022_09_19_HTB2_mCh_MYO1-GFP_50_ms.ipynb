# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bread.data import *
import bread.vis as vis

from pathlib import Path
import matplotlib.pyplot as plt

# %%
datafolder = Path('../../../data/data_from_LPBS/V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms')

# %%
seg = Segmentation.from_h5(datafolder / 'V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms.raw.2023-02-07.h5', fov='FOV0')
seg_new = seg.crop(315, 200, 1377, 1290)
seg_new.write_h5(datafolder / 'FOV0_segmentation.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'FOV0_BF.tif'), 180)
figax = vis.plot_segmentation(seg_new, 180, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms.raw.2023-02-07.h5', fov='FOV1')
seg_new = seg.crop(402, 180, 1563, 1335)
seg_new.write_h5(datafolder / 'FOV1_segmentation.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'FOV1_BF.tif'), 180)
figax = vis.plot_segmentation(seg_new, 180, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms.raw.2023-02-07.h5', fov='FOV2')
seg_new = seg.crop(384, 237, 1518, 1329)
seg_new.write_h5(datafolder / 'FOV2_segmentation.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'FOV2_BF.tif'), 180)
figax = vis.plot_segmentation(seg_new, 180, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms.raw.2023-02-07.h5', fov='FOV3')
seg_new = seg.crop(921, 391, 1127, 1017)
seg_new.write_h5(datafolder / 'FOV3_segmentation.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'FOV3_BF.tif'), 180)
figax = vis.plot_segmentation(seg_new, 180, cellids=False, figax=figax)

# %%
seg = Segmentation.from_h5(datafolder / 'V2022_09_19_HTB2_mCh_MYO1-GFP_50_ms.raw.2023-02-07.h5', fov='FOV4')
seg_new = seg.crop(752, 307, 1146, 1086)
seg_new.write_h5(datafolder / 'FOV4_segmentation.h5')
figax = vis.plot_visible(Microscopy.from_tiff(datafolder / 'FOV4_BF.tif'), 180)
figax = vis.plot_segmentation(seg_new, 180, cellids=False, figax=figax)

# %%
figax = vis.plot_visible(Microscopy.from_tiff('../../../data/data_from_LPBS/colony005_microscopy.tif'), 180)
figax = vis.plot_segmentation(Segmentation.from_h5('../../../data/data_from_LPBS/colony005_segmentation.h5'), 180, cellids=False, figax=figax)
